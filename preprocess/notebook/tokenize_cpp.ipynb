# %%
# import sys
# import os
# sys.path.append('../code/')
# from lang_processors2.cpp_processor import CppProcessor
# from clean_comment import remove_c_com_and_doc
# with open('../code/test_data/test.cpp', 'r', encoding='utf-8') as f:
#     codes = f.read()
# out = remove_c_com_and_doc(codes)
# processor = CppProcessor(root_folder='../code/lang_processors2/tree-sitter')
# out = processor.tokenize_code(out)
# print(out)

# %%
# import sys
# import os
# sys.path.append('../code/')
# from lang_processors2.cpp_processor import CppProcessor
# from clean_comment import remove_c_com_and_doc
# with open('../code/test_data/test3_1.cpp', 'r', encoding='utf-8') as f:
#     codes = f.read()
# out = remove_c_com_and_doc(codes)
# processor = CppProcessor(root_folder='../code/lang_processors2/tree-sitter')
# out = processor.tokenize_code(out)
# print(out)

# %%
import sys
import os
sys.path.append('../code/')
from lang_processors3.cpp_processor import CppProcessor
from lang_processors3.clean_comment import remove_c_com_and_doc
with open('../code/error.cpp', 'r', encoding='utf-8') as f:
    codes = f.read()
out = remove_c_com_and_doc(codes)
processor = CppProcessor(root_folder='../code/lang_processors3/tree-sitter')
out = processor.tokenize_code(out)
print(out)
# with open('error_after2.cpp', 'w') as f:
#     f.write(out)
# Out:
# #include   " dbusconnection _ p . h "
# #include   < QtDBus / QDBusMessage >
# #include   < qdebug . h >
# QT_BEGIN_NAMESPACE
# DBusConnection :: DBusConnection ( )
#      :   dbusConnection ( connectDBus ( ) )
# { }
# QDBusConnection   DBusConnection :: connectDBus ( )
# {
#      QString   address   =   getAccessibilityBusAddress ( ) ;
#      if   ( ! address . isEmpty ( ) )   {
#          QDBusConnection   c   =   QDBusConnection :: connectToBus ( address ,   QStringLiteral ( " a11y " ) ) ;
#          if   ( c . isConnected ( ) )   {
#              qDebug ( )   <<   " Connected ▁ to ▁ accessibility ▁ bus ▁ at : ▁ "   <<   address ;
#              return   c ;
#          }
#          qWarning ( " Found ▁ Accessibility ▁ DBus ▁ address ▁ but ▁ cannot ▁ connect . ▁ Falling ▁ back ▁ to ▁ session ▁ bus . " ) ;
#      }   else   {
#          qWarning ( " Accessibility ▁ DBus ▁ not ▁ found . ▁ Falling ▁ back ▁ to ▁ session ▁ bus . " ) ;
#      }
# ...

# %%
# import sys
# import os
# sys.path.append('../code/')
# from lang_processors3.cpp_processor import CppProcessor
# from clean_comment import remove_c_com_and_doc
# with open('../code/error2.cpp', 'r', encoding='utf-8') as f:
#     codes = f.read()
# out = remove_c_com_and_doc(codes)
# processor = CppProcessor(root_folder='../code/lang_processors3/tree-sitter')
# result = processor.tokenize_code(out)
# print(result)
# Out:
# #include   " dbusconnection _ p . h "
# #include   < QtDBus / QDBusMessage >
# #include   < qdebug . h >
# QT_BEGIN_NAMESPACE
# DBusConnection :: DBusConnection ( )
#      :   dbusConnection ( connectDBus ( ) )
# { }
# QDBusConnection   DBusConnection :: connectDBus ( )
# {
#      QString   address   =   getAccessibilityBusAddress ( ) ;
#      if   ( ! address . isEmpty ( ) )   {
#          QDBusConnection   c   =   QDBusConnection :: connectToBus ( address ,   QStringLiteral ( " a11y " ) ) ;
#          if   ( c . isConnected ( ) )   {
#              qDebug ( )   <<   " Connected ▁ to ▁ accessibility ▁ bus ▁ at : ▁ "   <<   address ;
#              return   c ;
#          }
#          qWarning ( " Found ▁ Accessibility ▁ DBus ▁ address ▁ but ▁ cannot ▁ connect . ▁ Falling ▁ back ▁ to ▁ session ▁ bus . " ) ;
#      }   else   {
#          qWarning ( " Accessibility ▁ DBus ▁ not ▁ found . ▁ Falling ▁ back ▁ to ▁ session ▁ bus . " ) ;
#      }
# ...

# %%
import sys
import os
sys.path.append('../code/')
from lang_processors4.cpp_processor import CppProcessor
from lang_processors4.clean_comment import remove_c_com_and_doc
with open('../code/test_data/test.cpp', 'r', encoding='utf-8') as f:
    codes = f.read()
out = remove_c_com_and_doc(codes)
processor = CppProcessor(root_folder='../code/lang_processors3/tree-sitter')
result = processor.tokenize_code(out)
print(result)
# Out:
# #include   " meta . h "
# #include   " option . h "
# #include   " project . h "
# #include   " winmakefile . h "
# #include   < qdir . h >
# #include   < qhash . h >
# #include   < qregexp . h >
# #include   < qstring . h >
# #include   < qstringlist . h >
# #include   < qtextstream . h >
# #include   < stdlib . h >
# QT BEGIN NAMESPACE
# Win32 Make file Generator :: Win32 Make file Generator ( )   :   Make file Generator ( )   { }
# int   Win32 Make file Generator :: find Highest Version ( const   Q String   & d ,
#                                                 const   Q String   & stem ,
#                                                 const   Q String   & ext )   {
#      Q String   bd   =   Option :: fix Path To Local OS ( d ,   true ) ;
#      if   ( ! exists ( bd ) )
#          return   <num> ;
#      Q Make Meta Info   lib info ;
#      bool   lib Info Read   =   lib info . read Lib ( bd   +   Option :: dir sep   +   stem ) ;
# ...
